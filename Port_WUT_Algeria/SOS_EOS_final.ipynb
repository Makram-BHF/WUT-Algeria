# %%
import os
import rasterio
import numpy as np
import geopandas as gpd
from rasterio import features
import pandas as pd
import subprocess
from joblib import Parallel, delayed

def get_decade_number(month, decade):
    """
    Convert year, month, and decade into a sequential decade number relative to a base year.
    """
    year_offset = 36
    month_offset = (month - 1) * 3
    return year_offset + month_offset + (decade - 1) + 1
def read_tif_values(tif_file_path, geometry):
    """
    Read values from a GeoTIFF file for a specific geometry.
    """
    with rasterio.open(tif_file_path) as src:
        mask = features.geometry_mask([geometry], out_shape=src.shape, transform=src.transform, invert=True)
        values = src.read(1, masked=True)[mask]
    return values

def find_growing_season(et_values):
    """
    Find the start and end of the growing season based on ET values.
    """
    peak_index = et_values.idxmax()
    before_peak = et_values[:peak_index].dropna()
    after_peak = et_values[peak_index:].dropna()

    start_index = None
    end_index = None

    if not before_peak.empty:
        before_diff = before_peak.diff()
        if not before_diff.empty and not before_diff.isna().all():
            start_index = before_diff.idxmax()

    if not after_peak.empty:
        after_diff = after_peak.diff()
        if not after_diff.empty and not after_diff.isna().all():
            end_index = after_diff.idxmin()

    return start_index, end_index

def write_tif(output_path, data, model_ds, dtype=rasterio.float32):
    """
    Write data to a GeoTIFF file.
    """
    with rasterio.open(
        output_path,
        'w',
        driver='GTiff',
        height=model_ds.height,
        width=model_ds.width,
        count=1,
        dtype=dtype,
        crs=model_ds.crs,
        transform=model_ds.transform,
    ) as dst:
        dst.write(data, 1)

def process_year(selected_year):
    """
    Process data for the selected year, starting from September of the previous year until May of the selected year.
    """
    print(f"Processing for year {selected_year}")

    # Load shapefile with segments
    gdf = gpd.read_file('/home/karim/WaPOR/data/algeria/segmentation/24tiles/V3/SNIC_30000_V2.shp')

    # Initialize arrays to store start and end decades for each segment
    start_decades = np.zeros(len(gdf), dtype='int')
    end_decades = np.zeros(len(gdf), dtype='int')

    # Load the model GeoTIFF to get its projection and resolution
    model_path = "/home/karim/WaPOR/data/algeria/segmentation/24tiles/V3/SNIC_30000_V2.tif"
    with rasterio.open(model_path) as model_ds:
        model_crs = model_ds.crs
        model_transform = model_ds.transform
        model_width = model_ds.width
        model_height = model_ds.height

        # Create empty arrays to store the results
        start_season_array = np.zeros((model_height, model_width), dtype='float32')
        end_season_array = np.zeros((model_height, model_width), dtype='float32')

    # List of TIFF files to be processed
    tif_directory = '/home/karim/WaPOR/data/algeria/outputs/AET_dekad/'
    tif_files = []
    tif_dates = []

    # Start from September of the previous year to May of the selected year
    for year, start_month, end_month in [(selected_year - 1, 9, 12), (selected_year, 1, 5)]:
        for month in range(start_month, end_month + 1):
            for decade in range(1, 4):
                decade_number = get_decade_number(month, decade)
                file_name = f"WAPOR-3.L3-AETI-D.MIT.{year}-{str(month).zfill(2)}-D{decade}.tif"
                file_path = os.path.join(tif_directory, file_name)
                if os.path.exists(file_path):
                    tif_files.append(file_path)
                    tif_dates.append(f"{year}-{str(month).zfill(2)}-D{decade}")

    print(tif_dates)
    for idx, row in gdf.iterrows():
        print(f"Processing segment {idx + 1} of {len(gdf)}")  # Progress print statement
        
        segment_et_values = []

        # Read ET values for each decade
        for tif_file in tif_files:
            values = read_tif_values(tif_file, row['geometry'])
            if len(values) > 0:
                segment_et_values.append(np.mean(values))  # Use the mean of the segment's values
            else:
                segment_et_values.append(np.nan)  # Handle cases where no values are found

        # Convert the list to a pandas Series for easier processing
        et_series = pd.Series(segment_et_values, index=tif_dates)

        # Calculate the start and end of the growing season
        start_idx, end_idx = find_growing_season(et_series)
        

        # Assign values to start and end decades, and also to the corresponding segment in the output arrays
        if start_idx is not None and not pd.isna(start_idx):
            year, month, decade = map(int, start_idx.split('-')[0:2] + [start_idx.split('-')[2][1]])
            start_decades[idx] = get_decade_number(month, decade)
        else:
            start_decades[idx] = 0  # Or handle it differently

        if end_idx is not None and not pd.isna(end_idx):
            year, month, decade = map(int, end_idx.split('-')[0:2] + [end_idx.split('-')[2][1]])
            end_decades[idx] = get_decade_number(month, decade)
        else:
            end_decades[idx] = 0  # Or handle it differently

        
        # Write the results to the final arrays
        geom = row['geometry']
        mask = features.geometry_mask([geom], out_shape=(model_height, model_width), transform=model_transform, invert=True)

        start_season_array[mask] = start_decades[idx]
        end_season_array[mask] = end_decades[idx]

        print ('here i have ',start_decades[idx],' ',end_decades[idx])

    # Write the start and end season arrays to GeoTIFF files
    output_start_tif = f'/home/karim/WaPOR/data/algeria/outputs/start_of_season_{selected_year}.tif'
    output_end_tif = f'/home/karim/WaPOR/data/algeria/outputs/end_of_season_{selected_year}.tif'

    write_tif(output_start_tif, start_season_array, model_ds)
    write_tif(output_end_tif, end_season_array, model_ds)

    print(f"Processing complete for year {selected_year}! Start and end season TIFF files have been created.")

# Example usage
process_year(2019)  # Process for the year 2019 (September 2018 to May 2019)
#process_year(2020)  # Process for the year 2020 (September 2019 to May 2020)

#num_cores = 5
#deks=[2019, 2020, 2021, 2022, 2023]
#Parallel(n_jobs=num_cores)(delayed(process_year)(yy) for yy in deks)
# Out:
# Processing for year 2019
# ['2018-09-D1', '2018-09-D2', '2018-09-D3', '2018-10-D1', '2018-10-D2', '2018-10-D3', '2018-11-D1', '2018-11-D2', '2018-11-D3', '2018-12-D1', '2018-12-D2', '2018-12-D3', '2019-01-D1', '2019-01-D2', '2019-01-D3', '2019-02-D1', '2019-02-D2', '2019-02-D3', '2019-03-D1', '2019-03-D2', '2019-03-D3', '2019-04-D1', '2019-04-D2', '2019-04-D3', '2019-05-D1', '2019-05-D2', '2019-05-D3']
# Processing segment 1 of 32903
# here i have  0   61
# Processing segment 2 of 32903
# here i have  0   61
# Processing segment 3 of 32903
# here i have  0   61
# Processing segment 4 of 32903
# here i have  0   61
# Processing segment 5 of 32903
# here i have  0   61
# Processing segment 6 of 32903
# here i have  0   61
# Processing segment 7 of 32903
# here i have  0   61
# Processing segment 8 of 32903
# here i have  0   61
# Processing segment 9 of 32903
# here i have  0   61
# Processing segment 10 of 32903
# here i have  0   61
# Processing segment 11 of 32903
# here i have  0   61
# Processing segment 12 of 32903
# here i have  0   61
# Processing segment 13 of 32903
# here i have  0   61
# Processing segment 14 of 32903
# here i have  0   61
# Processing segment 15 of 32903
# here i have  0   61
# Processing segment 16 of 32903
# here i have  0   61
# Processing segment 17 of 32903
# here i have  0   61
# Processing segment 18 of 32903
# here i have  0   61
# Processing segment 19 of 32903
# here i have  0   61
# Processing segment 20 of 32903
# here i have  0   61
# Processing segment 21 of 32903
# here i have  0   61
# Processing segment 22 of 32903
# here i have  0   61
# Processing segment 23 of 32903
# here i have  0   61
# Processing segment 24 of 32903
# here i have  0   61
# Processing segment 25 of 32903
# here i have  0   61
# Processing segment 26 of 32903
# here i have  0   61
# Processing segment 27 of 32903
# here i have  0   61
# Processing segment 28 of 32903
# here i have  0   61
# Processing segment 29 of 32903
# here i have  0   61
# Processing segment 30 of 32903
# here i have  0   61
# Processing segment 31 of 32903
# here i have  0   61
# Processing segment 32 of 32903
# here i have  0   61
# Processing segment 33 of 32903
# here i have  0   61
# Processing segment 34 of 32903
# here i have  0   61
# Processing segment 35 of 32903
# here i have  0   61
# Processing segment 36 of 32903
# here i have  0   61
# Processing segment 37 of 32903
# here i have  0   61
# Processing segment 38 of 32903
# here i have  0   61
# Processing segment 39 of 32903
# here i have  0   61
# Processing segment 40 of 32903
# here i have  0   61
# Processing segment 41 of 32903
# here i have  0   61
# Processing segment 42 of 32903
# here i have  0   61
# Processing segment 43 of 32903
# here i have  0   61
# Processing segment 44 of 32903
# here i have  0   61
# Processing segment 45 of 32903
# here i have  0   61
# Processing segment 46 of 32903
# here i have  0   61
# Processing segment 47 of 32903
# here i have  0   61
# Processing segment 48 of 32903
# here i have  0   61
# Processing segment 49 of 32903
# here i have  0   61
# Processing segment 50 of 32903
# here i have  0   61
# Processing segment 51 of 32903
# here i have  0   61
# Processing segment 52 of 32903
# here i have  0   61
# Processing segment 53 of 32903
# here i have  0   61
# Processing segment 54 of 32903
# here i have  0   61
# Processing segment 55 of 32903
# here i have  0   61
# Processing segment 56 of 32903
# here i have  0   61
# Processing segment 57 of 32903
# here i have  0   61
# Processing segment 58 of 32903
# here i have  0   61
# Processing segment 59 of 32903
# here i have  0   61
# Processing segment 60 of 32903
# here i have  0   61
# Processing segment 61 of 32903
# here i have  0   61
# Processing segment 62 of 32903
# here i have  0   61
# Processing segment 63 of 32903
# here i have  0   61
# Processing segment 64 of 32903
# here i have  0   61
# Processing segment 65 of 32903
# here i have  0   61
# Processing segment 66 of 32903
# here i have  0   61
# Processing segment 67 of 32903
# here i have  0   61
# Processing segment 68 of 32903
# here i have  0   61
# Processing segment 69 of 32903
# here i have  0   61
# Processing segment 70 of 32903
# here i have  0   61
# Processing segment 71 of 32903
# here i have  0   61
# Processing segment 72 of 32903
# here i have  0   61
# Processing segment 73 of 32903
# here i have  0   61
# Processing segment 74 of 32903
# here i have  0   61
# Processing segment 75 of 32903
# here i have  0   61
# Processing segment 76 of 32903
# here i have  0   61
# Processing segment 77 of 32903
# here i have  0   61
# Processing segment 78 of 32903
# here i have  0   61
# Processing segment 79 of 32903
# here i have  0   61
# Processing segment 80 of 32903
# here i have  0   61
# Processing segment 81 of 32903
# here i have  0   61
# Processing segment 82 of 32903
# here i have  0   61
# Processing segment 83 of 32903
# here i have  0   61
# Processing segment 84 of 32903
# here i have  0   61
# Processing segment 85 of 32903
# here i have  0   61
# Processing segment 86 of 32903
# here i have  0   61
# Processing segment 87 of 32903
# here i have  0   61
# Processing segment 88 of 32903
# here i have  0   61
# Processing segment 89 of 32903
# here i have  0   61
# Processing segment 90 of 32903
# here i have  0   61
# Processing segment 91 of 32903
# here i have  0   61
# Processing segment 92 of 32903
# here i have  0   61
# Processing segment 93 of 32903
# here i have  0   61
# Processing segment 94 of 32903
# here i have  0   61
# Processing segment 95 of 32903
# here i have  0   61
# Processing segment 96 of 32903
# here i have  0   61
# Processing segment 97 of 32903
# here i have  0   61
# Processing segment 98 of 32903
# here i have  0   61
# Processing segment 99 of 32903
# here i have  0   61
# Processing segment 100 of 32903
# here i have  0   61
# Processing segment 101 of 32903
# here i have  0   61
# Processing segment 102 of 32903
# here i have  0   61
# Processing segment 103 of 32903
# here i have  0   61
# Processing segment 104 of 32903
# here i have  0   61
# Processing segment 105 of 32903
# here i have  0   61
# Processing segment 106 of 32903
# here i have  0   61
# Processing segment 107 of 32903
# here i have  0   61
# Processing segment 108 of 32903
# here i have  0   61
# Processing segment 109 of 32903
# here i have  0   61
# Processing segment 110 of 32903
# here i have  0   61
# Processing segment 111 of 32903
# here i have  0   61
# Processing segment 112 of 32903
# here i have  0   61
# Processing segment 113 of 32903
# here i have  0   61
# Processing segment 114 of 32903
# here i have  0   61
# Processing segment 115 of 32903
# here i have  0   61
# Processing segment 116 of 32903
# here i have  0   61
# Processing segment 117 of 32903
# here i have  0   61
# Processing segment 118 of 32903
# here i have  0   61
# Processing segment 119 of 32903
# here i have  0   61
# Processing segment 120 of 32903
# here i have  0   61
# Processing segment 121 of 32903
# here i have  0   61
# Processing segment 122 of 32903
# here i have  0   61
# Processing segment 123 of 32903
# here i have  0   61
# Processing segment 124 of 32903
# here i have  0   61
# Processing segment 125 of 32903
# here i have  0   61
# Processing segment 126 of 32903
# here i have  0   61
# Processing segment 127 of 32903
# here i have  0   61
# Processing segment 128 of 32903
# here i have  0   61
# Processing segment 129 of 32903
# here i have  0   61
# Processing segment 130 of 32903
# here i have  0   61
# Processing segment 131 of 32903
# here i have  0   61
# Processing segment 132 of 32903
# here i have  0   61
# Processing segment 133 of 32903
# here i have  0   61
# Processing segment 134 of 32903
# here i have  0   61
# Processing segment 135 of 32903
# here i have  0   61
# Processing segment 136 of 32903
# here i have  0   61
# Processing segment 137 of 32903
# here i have  0   61
# Processing segment 138 of 32903
# here i have  0   61
# Processing segment 139 of 32903
# here i have  0   61
# Processing segment 140 of 32903
# here i have  0   61
# Processing segment 141 of 32903
# here i have  0   61
# Processing segment 142 of 32903
# here i have  0   61
# Processing segment 143 of 32903
# here i have  0   61
# Processing segment 144 of 32903
# here i have  0   61
# Processing segment 145 of 32903
# here i have  0   61
# Processing segment 146 of 32903
# here i have  0   61
# Processing segment 147 of 32903
# here i have  0   61
# Processing segment 148 of 32903
# here i have  0   61
# Processing segment 149 of 32903
# here i have  0   61
# Processing segment 150 of 32903
# here i have  0   61
# Processing segment 151 of 32903
# here i have  0   61
# Processing segment 152 of 32903
# here i have  0   61
# Processing segment 153 of 32903
# here i have  0   61
# Processing segment 154 of 32903
# here i have  0   61
# Processing segment 155 of 32903
# here i have  0   61
# Processing segment 156 of 32903
# here i have  0   61
# Processing segment 157 of 32903
# here i have  0   61
# Processing segment 158 of 32903
# here i have  0   61
# Processing segment 159 of 32903
# here i have  0   61
# Processing segment 160 of 32903
# here i have  0   61
# Processing segment 161 of 32903
# here i have  0   61
# Processing segment 162 of 32903
# here i have  0   61
# Processing segment 163 of 32903
# here i have  0   61
# Processing segment 164 of 32903
# here i have  0   61
# Processing segment 165 of 32903
# here i have  0   61
# Processing segment 166 of 32903
# here i have  0   61
# Processing segment 167 of 32903
# here i have  0   61
# Processing segment 168 of 32903
# here i have  0   61
# Processing segment 169 of 32903
# here i have  0   61
# Processing segment 170 of 32903
# here i have  0   61
# Processing segment 171 of 32903
# here i have  0   61
# Processing segment 172 of 32903
# here i have  0   61
# Processing segment 173 of 32903
# here i have  0   61
# Processing segment 174 of 32903
# here i have  0   61
# Processing segment 175 of 32903
# here i have  0   61
# Processing segment 176 of 32903
# here i have  0   61
# Processing segment 177 of 32903
# here i have  0   61
# Processing segment 178 of 32903
# here i have  0   61
# Processing segment 179 of 32903
# here i have  0   61
# Processing segment 180 of 32903
# here i have  0   61
# Processing segment 181 of 32903
# here i have  0   61
# Processing segment 182 of 32903
# here i have  0   61
# Processing segment 183 of 32903
# here i have  0   61
# Processing segment 184 of 32903
# here i have  0   61
# Processing segment 185 of 32903
# here i have  0   61
# Processing segment 186 of 32903
# here i have  0   61
# Processing segment 187 of 32903
# here i have  0   61
# Processing segment 188 of 32903
# here i have  0   61
# Processing segment 189 of 32903
# here i have  0   61
# Processing segment 190 of 32903
# here i have  0   61
# Processing segment 191 of 32903
# here i have  0   61
# Processing segment 192 of 32903
# here i have  0   61
# Processing segment 193 of 32903
# here i have  0   61
# Processing segment 194 of 32903
# here i have  0   61
# Processing segment 195 of 32903
# here i have  0   61
# Processing segment 196 of 32903
# here i have  0   61
# Processing segment 197 of 32903
# here i have  0   61
# Processing segment 198 of 32903
# here i have  0   61
# Processing segment 199 of 32903
# here i have  0   61
# Processing segment 200 of 32903
# here i have  0   61
# Processing segment 201 of 32903
# here i have  0   61
# Processing segment 202 of 32903
# here i have  0   61
# Processing segment 203 of 32903
# here i have  0   61
# Processing segment 204 of 32903
# here i have  0   61
# Processing segment 205 of 32903
# here i have  0   61
# Processing segment 206 of 32903
# here i have  0   61
# Processing segment 207 of 32903
# here i have  0   61
# Processing segment 208 of 32903
# here i have  0   61
# Processing segment 209 of 32903
# here i have  0   61
# Processing segment 210 of 32903
# here i have  0   61
# Processing segment 211 of 32903
# here i have  0   61
# Processing segment 212 of 32903
# here i have  0   61
# Processing segment 213 of 32903
# here i have  0   61
# Processing segment 214 of 32903
# here i have  0   61
# Processing segment 215 of 32903
# here i have  0   61
# Processing segment 216 of 32903
# here i have  0   61
# Processing segment 217 of 32903
# here i have  0   61
# Processing segment 218 of 32903
# here i have  0   61
# Processing segment 219 of 32903
# here i have  0   61
# Processing segment 220 of 32903
# here i have  0   61
# Processing segment 221 of 32903
# here i have  0   61
# Processing segment 222 of 32903
# here i have  0   61
# Processing segment 223 of 32903
# here i have  0   61
# Processing segment 224 of 32903
# here i have  0   61
# Processing segment 225 of 32903
# here i have  0   61
# Processing segment 226 of 32903
# here i have  0   61
# Processing segment 227 of 32903
# here i have  0   61
# Processing segment 228 of 32903
# here i have  0   61
# Processing segment 229 of 32903
# here i have  0   61
# Processing segment 230 of 32903
# here i have  0   61
# Processing segment 231 of 32903
# here i have  0   61
# Processing segment 232 of 32903
# here i have  0   61
# Processing segment 233 of 32903
# here i have  0   61
# Processing segment 234 of 32903
# here i have  0   61
# Processing segment 235 of 32903
# here i have  0   61
# Processing segment 236 of 32903
# here i have  0   61
# Processing segment 237 of 32903
# here i have  0   61
# Processing segment 238 of 32903
# here i have  0   61
# Processing segment 239 of 32903
# here i have  0   61
# Processing segment 240 of 32903
# here i have  0   61
# Processing segment 241 of 32903
# here i have  0   61
# Processing segment 242 of 32903
# here i have  0   61
# Processing segment 243 of 32903
# here i have  0   61
# Processing segment 244 of 32903
# here i have  0   61
# Processing segment 245 of 32903
# here i have  0   61
# Processing segment 246 of 32903
# here i have  0   61
# Processing segment 247 of 32903
# here i have  0   61
# Processing segment 248 of 32903
# here i have  0   61
# Processing segment 249 of 32903
# here i have  0   61
# Processing segment 250 of 32903
# here i have  0   61
# Processing segment 251 of 32903
# here i have  0   61
# Processing segment 252 of 32903
# here i have  0   61
# Processing segment 253 of 32903
# here i have  0   61
# Processing segment 254 of 32903
# here i have  0   61
# Processing segment 255 of 32903
# here i have  0   61
# Processing segment 256 of 32903
# here i have  0   61
# Processing segment 257 of 32903
# here i have  0   61
# Processing segment 258 of 32903
# here i have  0   61
# Processing segment 259 of 32903
# here i have  0   61
# Processing segment 260 of 32903
# here i have  0   61
# Processing segment 261 of 32903
# here i have  0   61
# Processing segment 262 of 32903
# here i have  0   61
# Processing segment 263 of 32903
# here i have  0   61
# Processing segment 264 of 32903
# here i have  0   61
# Processing segment 265 of 32903
# here i have  0   61
# Processing segment 266 of 32903
# here i have  0   61
# Processing segment 267 of 32903
# here i have  0   61
# Processing segment 268 of 32903
# here i have  0   61
# Processing segment 269 of 32903
# here i have  0   61
# Processing segment 270 of 32903
# here i have  0   61
# Processing segment 271 of 32903
# here i have  0   61
# Processing segment 272 of 32903
# here i have  0   61
# Processing segment 273 of 32903
# here i have  0   61
# Processing segment 274 of 32903
# here i have  0   61
# Processing segment 275 of 32903
# here i have  0   61
# Processing segment 276 of 32903
# here i have  0   61
# Processing segment 277 of 32903
# here i have  0   61
# Processing segment 278 of 32903
# here i have  0   61
# Processing segment 279 of 32903
# here i have  0   61
# Processing segment 280 of 32903
# here i have  0   61
# Processing segment 281 of 32903
# here i have  0   61
# Processing segment 282 of 32903
# here i have  0   61
# Processing segment 283 of 32903
# here i have  0   61
# Processing segment 284 of 32903
# here i have  0   61
# Processing segment 285 of 32903
# here i have  0   61
# Processing segment 286 of 32903
# here i have  0   61
# Processing segment 287 of 32903
# here i have  0   61
# Processing segment 288 of 32903
# here i have  0   61
# Processing segment 289 of 32903
# here i have  0   61
# Processing segment 290 of 32903
# here i have  0   61
# Processing segment 291 of 32903
# here i have  0   61
# Processing segment 292 of 32903
# here i have  0   61
# Processing segment 293 of 32903
# here i have  0   61
# Processing segment 294 of 32903
# here i have  0   61
# Processing segment 295 of 32903
# here i have  0   61
# Processing segment 296 of 32903
# here i have  0   61
# Processing segment 297 of 32903
# here i have  0   61
# Processing segment 298 of 32903
# here i have  0   61
# Processing segment 299 of 32903
# here i have  0   61
# Processing segment 300 of 32903
# here i have  0   61
# Processing segment 301 of 32903
# here i have  0   61
# Processing segment 302 of 32903
# here i have  0   61
# Processing segment 303 of 32903
# here i have  0   61
# Processing segment 304 of 32903
# here i have  0   61
# Processing segment 305 of 32903
# here i have  0   61
# Processing segment 306 of 32903
# here i have  0   61
# Processing segment 307 of 32903
# here i have  0   61
# Processing segment 308 of 32903
# here i have  63   51
# Processing segment 309 of 32903
# here i have  39   45
# Processing segment 310 of 32903
# here i have  63   48
# Processing segment 311 of 32903
# here i have  63   70
# Processing segment 312 of 32903
# here i have  65   70
# Processing segment 313 of 32903
# here i have  65   70
# Processing segment 314 of 32903
# here i have  69   48
# Processing segment 315 of 32903
# here i have  63   51
# Processing segment 316 of 32903
# here i have  65   70
# Processing segment 317 of 32903
# here i have  39   51
# Processing segment 318 of 32903
# here i have  63   51
# Processing segment 319 of 32903
# here i have  47   51
# Processing segment 320 of 32903
# here i have  63   64
# Processing segment 321 of 32903
# here i have  39   42
# Processing segment 322 of 32903
# here i have  50   51
# Processing segment 323 of 32903
# here i have  65   51
# Processing segment 324 of 32903
# here i have  65   51
# Processing segment 325 of 32903
# here i have  39   51
# Processing segment 326 of 32903
# here i have  63   70
# Processing segment 327 of 32903
# here i have  39   51
# Processing segment 328 of 32903
# here i have  39   51
# Processing segment 329 of 32903
# here i have  63   70
# Processing segment 330 of 32903
# here i have  63   70
# Processing segment 331 of 32903
# here i have  63   70
# Processing segment 332 of 32903
# here i have  63   51
# Processing segment 333 of 32903
# here i have  47   51
# Processing segment 334 of 32903
# here i have  63   70
# Processing segment 335 of 32903
# here i have  63   51
# Processing segment 336 of 32903
# here i have  63   64
# Processing segment 337 of 32903
# here i have  50   51
# Processing segment 338 of 32903
# here i have  63   64
# Processing segment 339 of 32903
# here i have  39   51
# Processing segment 340 of 32903
# here i have  39   51
# Processing segment 341 of 32903
# here i have  49   51
# Processing segment 342 of 32903
# here i have  39   51
# Processing segment 343 of 32903
# here i have  39   51
# Processing segment 344 of 32903
# here i have  39   51
# Processing segment 345 of 32903
# here i have  39   51
# Processing segment 346 of 32903
# here i have  39   51
# Processing segment 347 of 32903
# here i have  63   64
# Processing segment 348 of 32903
# here i have  63   64
# Processing segment 349 of 32903
# here i have  47   51
# Processing segment 350 of 32903
# here i have  47   51
# Processing segment 351 of 32903
# here i have  50   51
# Processing segment 352 of 32903
# here i have  49   51
# Processing segment 353 of 32903
# here i have  63   51
# Processing segment 354 of 32903
# here i have  47   51
# Processing segment 355 of 32903
# here i have  63   64
# Processing segment 356 of 32903
# here i have  39   51
# Processing segment 357 of 32903
# here i have  0   61
# Processing segment 358 of 32903
# here i have  0   61
# Processing segment 359 of 32903
# here i have  0   61
# Processing segment 360 of 32903
# here i have  0   61
# Processing segment 361 of 32903
# here i have  0   61
# Processing segment 362 of 32903
# here i have  0   61
# Processing segment 363 of 32903
# here i have  0   61
# Processing segment 364 of 32903
# here i have  0   61
# Processing segment 365 of 32903
# here i have  0   61
# Processing segment 366 of 32903
# here i have  0   61
# Processing segment 367 of 32903
# here i have  0   61
# Processing segment 368 of 32903
# here i have  0   61
# Processing segment 369 of 32903
# here i have  0   61
# Processing segment 370 of 32903
# here i have  0   61
# Processing segment 371 of 32903
# here i have  0   61
# Processing segment 372 of 32903
# here i have  0   61
# Processing segment 373 of 32903
# here i have  0   61
# Processing segment 374 of 32903
# here i have  0   61
# Processing segment 375 of 32903
# here i have  0   61
# Processing segment 376 of 32903
# here i have  0   61
# Processing segment 377 of 32903
# here i have  0   61
# Processing segment 378 of 32903
# here i have  0   61
# Processing segment 379 of 32903
# here i have  0   61
# Processing segment 380 of 32903
# here i have  0   61
# Processing segment 381 of 32903
# here i have  0   61
# Processing segment 382 of 32903
# here i have  0   61
# Processing segment 383 of 32903
# here i have  0   61
# Processing segment 384 of 32903
# here i have  0   61
# Processing segment 385 of 32903
# here i have  0   61
# Processing segment 386 of 32903
# here i have  0   61
# Processing segment 387 of 32903
# here i have  0   61
# Processing segment 388 of 32903
# here i have  0   61
# Processing segment 389 of 32903
# here i have  0   61
# Processing segment 390 of 32903
# here i have  0   61
# Processing segment 391 of 32903
# here i have  0   61
# Processing segment 392 of 32903
# here i have  0   61
# Processing segment 393 of 32903
# here i have  0   61
# Processing segment 394 of 32903
# here i have  0   61
# Processing segment 395 of 32903
# here i have  0   61
# Processing segment 396 of 32903
# here i have  0   61
# Processing segment 397 of 32903
# here i have  0   61
# Processing segment 398 of 32903
# here i have  0   61
# Processing segment 399 of 32903
# here i have  0   61
# Processing segment 400 of 32903
# here i have  0   61
# Processing segment 401 of 32903
# here i have  0   61
# Processing segment 402 of 32903
# here i have  0   61
# Processing segment 403 of 32903
# here i have  0   61
# Processing segment 404 of 32903
# here i have  0   61
# Processing segment 405 of 32903
# here i have  0   61
# Processing segment 406 of 32903
# here i have  0   61
# Processing segment 407 of 32903
# here i have  0   61
# Processing segment 408 of 32903
# here i have  0   61
# Processing segment 409 of 32903
# here i have  0   61
# Processing segment 410 of 32903
# here i have  0   61
# Processing segment 411 of 32903
# here i have  0   61
# Processing segment 412 of 32903
# here i have  0   61
# Processing segment 413 of 32903
# here i have  0   61
# Processing segment 414 of 32903
# here i have  0   61
# Processing segment 415 of 32903
# here i have  0   61
# Processing segment 416 of 32903
# here i have  0   61
# Processing segment 417 of 32903
# here i have  0   61
# Processing segment 418 of 32903
# here i have  0   61
# Processing segment 419 of 32903
# here i have  0   61
# Processing segment 420 of 32903
# here i have  0   61
# Processing segment 421 of 32903
# here i have  0   61
# Processing segment 422 of 32903
# here i have  0   61
# Processing segment 423 of 32903
# here i have  0   61
# Processing segment 424 of 32903
# here i have  0   61
# Processing segment 425 of 32903
# here i have  0   61
# Processing segment 426 of 32903
# here i have  0   61
# Processing segment 427 of 32903
# here i have  0   61
# Processing segment 428 of 32903
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 161
#     158     print(f"Processing complete for year {selected_year}! Start and end season TIFF files have been created.")
#     160 # Example usage
# --> 161 process_year(2019)  # Process for the year 2019 (September 2018 to May 2019)
#     162 #process_year(2020)  # Process for the year 2020 (September 2019 to May 2020)
#     163
#     164 #num_cores = 5
#     165 #deks=[2019, 2020, 2021, 2022, 2023]
#     166 #Parallel(n_jobs=num_cores)(delayed(process_year)(yy) for yy in deks)
#
# Cell In[1], line 115, in process_year(selected_year)
#     113 # Read ET values for each decade
#     114 for tif_file in tif_files:
# --> 115     values = read_tif_values(tif_file, row['geometry'])
#     116     if len(values) > 0:
#     117         segment_et_values.append(np.mean(values))  # Use the mean of the segment's values
#
# Cell In[1], line 23, in read_tif_values(tif_file_path, geometry)
#      21 with rasterio.open(tif_file_path) as src:
#      22     mask = features.geometry_mask([geometry], out_shape=src.shape, transform=src.transform, invert=True)
# ---> 23     values = src.read(1, masked=True)[mask]
#      24 return values
#
# File rasterio/_io.pyx:671, in rasterio._io.DatasetReaderBase.read()
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/ma/core.py:6660, in array(data, dtype, copy, order, mask, fill_value, keep_mask, hard_mask, shrink, subok, ndmin)
#    6656 masked = masked_singleton = MaskedConstant()
#    6657 masked_array = MaskedArray
# -> 6660 def array(data, dtype=None, copy=False, order=None,
#    6661           mask=nomask, fill_value=None, keep_mask=True,
#    6662           hard_mask=False, shrink=True, subok=True, ndmin=0):
#    6663     """
#    6664     Shortcut to MaskedArray.
#    6665
#    (...)
#    6668
#    6669     """
#    6670     return MaskedArray(data, mask=mask, dtype=dtype, copy=copy,
#    6671                        subok=subok, keep_mask=keep_mask,
#    6672                        hard_mask=hard_mask, fill_value=fill_value,
#    6673                        ndmin=ndmin, shrink=shrink, order=order)
#
# KeyboardInterrupt:
