# %%
import os
from osgeo import gdal, osr, ogr
import numpy as np
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling
from pyproj import Transformer
from rasterio.mask import mask
from shapely.geometry import box
from rasterio import features
import geopandas as gpd
import subprocess
from joblib import Parallel, delayed

output_file = '/home/karim/WaPOR/data/algeria/outputs/tmp2/reproj_'
input_file = '/home/karim/WaPOR/data/algeria/outputs/tmp2/reproj_cropped_'
resampled_file = "/home/karim/WaPOR/data/algeria/outputs/tmp2/resampled_output_"
my_shpfile = "/home/karim/WaPOR/data/algeria/segmentation/24tiles/V3/SNIC_30000_V2.shp"
mask_file_path = "/home/karim/WaPOR/data/algeria/segmentation/24tiles/V3/SNIC_30000_V2.tif"

start_year = 23 #18
end_year = 24

# Define the number of decades for each year
num_decades = {
    18: 36,
    19: 36,
    20: 36,
    21: 36,
    22: 36,
    23: 36,
    24: 9
}

# Define the list of dekads using list comprehension
deks = [f"{year:02}{decade:02}" for year in range(start_year, end_year + 1) for decade in range(1, num_decades.get(year, 1) + 1)]

#print(deks)
num_cores=4

def update_tif_with_mask(tif_file_path, mask_file_path, output_file_path, mask_value=-1):
    # Open the GeoTIFF file
    with rasterio.open(tif_file_path, 'r') as tif_dataset:
        # Read the data as a NumPy array
        tif_data = tif_dataset.read(1)
        
        # Set all values below -1 to nodata
        nodata_value = tif_dataset.profile['nodata']
        tif_data[tif_data < -1] = nodata_value

        # Open the mask file
        with rasterio.open(mask_file_path, 'r') as mask_dataset:
            # Read the mask data as a NumPy array
            mask_data = mask_dataset.read(1)

            # Check if the extent, projection, and pixel numbers match
            if tif_dataset.bounds == mask_dataset.bounds and \
               tif_dataset.crs == mask_dataset.crs and \
               tif_dataset.width == mask_dataset.width and \
               tif_dataset.height == mask_dataset.height:

                # Replace pixels in the TIF file where the mask is equal to the specified value with NaN
                tif_data[mask_data == mask_value] = nodata_value

                # Create a new GeoTIFF file with updated values
                with rasterio.open(output_file_path, 'w', **tif_dataset.profile) as output_dataset:
                    output_dataset.write(tif_data, 1)

                print("Operation completed successfully.")
            else:
                print("Error: The extent, projection, or pixel numbers of the two datasets do not match.")

def avg_seg(filein, fileout):
    with rasterio.open(filein) as src:
        transform = src.transform
        dtype = src.dtypes[0]
        nodata = -9999  # Set nodata value to -9999
        height, width = src.height, src.width
        shapefile = gpd.read_file(my_shpfile)
        shapefile = shapefile.to_crs(src.crs)
        shapefile_bounds = shapefile.total_bounds
        shapefile_polygon = box(*shapefile_bounds)
        raster_cropped, transform_cropped = mask(src, [shapefile_polygon], crop=True)
        height_cropped, width_cropped = raster_cropped.shape[1:]
        raster_data_cropped = raster_cropped[0]
        raster_data_cropped[raster_data_cropped < -1] = nodata  # Set all values below -1 to nodata
        output_data = np.full((height_cropped, width_cropped), nodata, dtype=dtype)
        for idx, feature in shapefile.iterrows():
            geometry = feature.geometry
            feature_mask = features.geometry_mask([geometry], out_shape=(height_cropped, width_cropped), transform=transform_cropped)
            masked_values = np.ma.array(raster_data_cropped, mask=~feature_mask, fill_value=nodata)
            if np.any(masked_values.mask == True):
                average_value = np.nanmean(masked_values.data[masked_values.mask == True])
            else:
                average_value = nodata
            output_data[masked_values.mask == True] = average_value
        with rasterio.open(fileout, 'w', driver='GTiff', height=height_cropped,
                           width=width_cropped, count=1, dtype=dtype, nodata=nodata, crs=src.crs,
                           transform=transform_cropped) as dst:
            dst.write(output_data, 1)    
    raster_cropped = None
    shapefile = None

def process_nmfic(nmfic):
    input_raw_file = "/home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0." + nmfic + ".tif"
    #final_file = "/home/karim/WaPOR/data/tunisia/outputs/chirps/AVG_50k_20" + nmfic + ".tif"
    final_file = "/home/karim/WaPOR/data/algeria/outputs/tmp2/AVG_50k_20" + nmfic + ".tif"
    output_file_path = "/home/karim/WaPOR/data/algeria/outputs/chirps/AVG_50k_20" + nmfic + ".tif"
    print('Traitement de ...', input_raw_file)
    src_srs = osr.SpatialReference()
    src_srs.ImportFromEPSG(4326)
    target_srs = osr.SpatialReference()
    target_srs.ImportFromEPSG(32631)
    try:
        input_ds = gdal.Open(input_raw_file)
        if input_ds is not None:
            output_file1=output_file+nmfic+'.tif'
            reproj_ds = gdal.Warp(output_file1, input_ds, format='GTiff', dstSRS=target_srs)
            geotransform = reproj_ds.GetGeoTransform()
            input_ds = None
            reproj_ds = None
        else:
            print("Failed to open the input file.")

    except Exception as e:
        print("An error occurred:", str(e))
    shapefile_ds = ogr.Open(my_shpfile)
    layer = shapefile_ds.GetLayer()
    extent = layer.GetExtent()
    output_raster = input_file+nmfic+'.tif' #"/home/wapor/reproj_cropped.tif"  # Save under /home/wapor directory
    output_file1=output_file+nmfic+'.tif'
    gdal.Warp(
        output_raster,
        output_file1,
        format="GTiff",
        outputBounds=(extent[0], extent[2], extent[1], extent[3]),  # Use the shapefile's bounding box
    )
    shapefile_ds = None
    #output_raster = None
    #output_raster = None
    snic_ds = gdal.Open(my_shpfile.replace(".shp", ".tif"))  # Assuming it's a GeoTIFF
    target_resolution = snic_ds.GetGeoTransform()[1]
    snic_ds= None
    output_raster = gdal.Open(output_raster, gdal.GA_Update)
    #input_file1=input_file+nmfic+'.tif'
    #input_ds = gdal.Open(input_file1, gdal.GA_Update)
    resampled_file1 = resampled_file + nmfic + '.tif'
    try:
        gdal.Warp(
        resampled_file1,
        output_raster,
        format="GTiff",
        outputBounds=(extent[0], extent[2], extent[1], extent[3]),
        xRes=target_resolution,
        yRes=target_resolution,
        creationOptions=["TILED=YES", "COMPRESS=LZW"]
    )
    except Exception as e:
        print("An error occurred:", str(e))
    avg_seg(resampled_file1, final_file)
    output_raster = None
    os.remove(output_file1)
    #os.remove(output_raster)
    os.remove(resampled_file1)

    # Maski
    update_tif_with_mask(final_file, mask_file_path, output_file_path)

if __name__ == '__main__':
    # Use joblib to parallelize the processing of deks1[0] and deks1[1] on separate cores.
    Parallel(n_jobs=num_cores)(delayed(process_nmfic)(nmfic) for nmfic in deks)
# Out:
# /home/karim/miniconda3/lib/python3.12/site-packages/osgeo/osr.py:410: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# /home/karim/miniconda3/lib/python3.12/site-packages/osgeo/osr.py:410: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# /home/karim/miniconda3/lib/python3.12/site-packages/osgeo/osr.py:410: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# /home/karim/miniconda3/lib/python3.12/site-packages/osgeo/osr.py:410: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2303.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2306.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2310.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2314.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2318.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2322.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2326.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2330.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2334.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2402.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2406.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2304.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2307.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2311.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2315.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2319.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2323.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2327.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2331.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2335.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2403.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2407.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2302.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2308.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2312.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2316.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2320.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2324.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2328.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2332.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2336.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2404.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2408.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2301.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2305.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2309.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2313.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2317.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2321.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2325.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2329.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2333.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2401.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2405.tif
# Operation completed successfully.
# Traitement de ... /home/karim/WaPOR/data/tunisia/chirps_dekad/tif/chirps-v2.0.2409.tif
# Operation completed successfully.
